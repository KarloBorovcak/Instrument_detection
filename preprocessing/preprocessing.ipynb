# %% [markdown]
# # Preprocessing audio data

# %%
import librosa
import librosa.display
import matplotlib.pyplot as plt
import numpy as np

# %%
# Load the audio file
audio_path = '../../DataLumenDS/Dataset/IRMAS_Training_Data/cel/[cel][cla]0001__1.wav'
x , sr = librosa.load(audio_path, sr=44100, mono=False)



# Plot the audio file
#plt.figure(figsize=(14, 5))
librosa.display.waveshow(x, sr=sr)

# %%
x =np.pad(np.array([1,1,1,1]), (0, 1), mode="constant")
x
# Out:
# array([1, 1, 1, 1, 0])

# %%
path = '../../DataLumenDS/Processed/flu/[flu][cla]0346__1.wav_0.npy'
path_cel = '../../DataLumenDS/Processed/cel/[cel][cla]0001__1.wav_0.npy'
path_X = '../X_train.npy'

signal = np.load(path_X)
print(signal[5].shape)
lol = librosa.display.specshow(signal[1], sr=22050, x_axis='time', y_axis='mel')
plt.savefig('test.png')
# Out:
# (128, 44)

# %%
signal
# Out:
# array([[[-24.23862267, -29.69299507, -30.55019379, ..., -20.32137871,
#          -27.77471161, -25.23927307],
#         [ -9.13067913,  -3.50816703,  -5.70846605, ...,  -6.69704199,
#           -1.72208905,  -8.75740623],
#         [  1.59927475,  -0.36191678,  -3.66092873, ...,   5.98471165,
#           10.75507355,  -5.14028168],
#         ...,
#         [-48.17246246, -48.17246246, -48.17246246, ..., -48.17246246,
#          -48.17246246, -48.17246246],
#         [-48.17246246, -48.17246246, -48.17246246, ..., -48.17246246,
#          -48.17246246, -48.17246246],
#         [-48.17246246, -48.17246246, -48.17246246, ..., -48.17246246,
#          -48.17246246, -48.17246246]],
#
#        [[-10.5572471 , -15.45585188, -24.92235633, ..., -16.05351529,
#          -10.22039832, -25.0717767 ],
#         [ -2.46064499,  -0.24198098,  -5.61046473, ...,  -5.35903627,
#           -2.5475236 ,  -9.2716351 ],
#         [  6.35113763,  -0.35658188,  -3.95620904, ...,   4.13767356,
# ...

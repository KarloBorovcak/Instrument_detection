# %% [markdown]
# # Preprocessing audio data

# %%
import librosa
import librosa.display
import matplotlib.pyplot as plt
import numpy as np

# %%
# Load the audio file
audio_path = '../../DataLumenDS/Dataset/IRMAS_Training_Data/cel/[cel][cla]0001__1.wav'
x , sr = librosa.load(audio_path)

# Plot the audio file
plt.figure(figsize=(14, 5))
librosa.display.waveshow(x, sr=sr)

# %%
# Extract the MFCCs
mfccs = librosa.feature.mfcc(x, sr=sr)

# Plot the MFCCs
plt.figure(figsize=(10, 4))
librosa.display.specshow(mfccs, x_axis='time')

# Extract the chroma features
chroma = librosa.feature.chroma_stft(x, sr=sr, hop_length=512)

# Plot the chroma features
plt.figure(figsize=(10, 4))
librosa.display.specshow(chroma, x_axis='time', y_axis='chroma', hop_length=512)

# Extract the mel spectrogram
mel = librosa.feature.melspectrogram(x, sr=sr)

# Plot the mel spectrogram
plt.figure(figsize=(10, 4))
librosa.display.specshow(librosa.power_to_db(mel, ref=np.max), x_axis='time', y_axis='mel', sr=sr, hop_length=512)
# Out:
# C:\Users\Karlo\AppData\Local\Temp\ipykernel_4712\1343474939.py:2: FutureWarning: Pass y=[ 0.0167555   0.02817065  0.0262885  ... -0.035854   -0.02864175
#   0.        ] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mfccs = librosa.feature.mfcc(x, sr=sr)
# C:\Users\Karlo\AppData\Local\Temp\ipykernel_4712\1343474939.py:9: FutureWarning: Pass y=[ 0.0167555   0.02817065  0.0262885  ... -0.035854   -0.02864175
#   0.        ] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   chroma = librosa.feature.chroma_stft(x, sr=sr, hop_length=512)
# C:\Users\Karlo\AppData\Local\Temp\ipykernel_4712\1343474939.py:16: FutureWarning: Pass y=[ 0.0167555   0.02817065  0.0262885  ... -0.035854   -0.02864175
#   0.        ] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel = librosa.feature.melspectrogram(x, sr=sr)

# %% [markdown]
# # Preprocessing audio data

# %%
import librosa
import librosa.display
import matplotlib.pyplot as plt
import numpy as np

# %%
# Load the audio file
audio_path = '../../DataLumenDS/Dataset/IRMAS_Training_Data/cel/[cel][cla]0001__1.wav'
x , sr = librosa.load(audio_path, sr=44100, mono=False)



# Plot the audio file
plt.figure(figsize=(14, 5))
librosa.display.waveshow(x, sr=sr)

# %%
audio_path = '../../DataLumenDS/Processed/cel/[cel][cla]0001__1.wav.npy'
cla = '../../DataLumenDS/Processed/pia/[pia][cla]1283__1.wav.npy'

x2 = np.load(cla)
x2.shape
librosa.display.specshow(x2, sr=sr, x_axis='time', y_axis='mel')
# Out:
# array([[0.7064805 , 0.5019263 , 0.40013948, ..., 0.5484675 , 0.5838187 ,
#         0.4233373 ],
#        [0.7034855 , 0.28907758, 0.5549894 , ..., 0.6268862 , 0.45450807,
#         0.52746797],
#        [0.7042962 , 0.57178   , 0.63470775, ..., 0.7076509 , 0.6344517 ,
#         0.65010035],
#        ...,
#        [0.03376646, 0.        , 0.        , ..., 0.        , 0.        ,
#         0.05183659],
#        [0.0333931 , 0.        , 0.        , ..., 0.        , 0.        ,
#         0.05161095],
#        [0.0332243 , 0.        , 0.        , ..., 0.        , 0.        ,
#         0.05151033]], dtype=float32)
